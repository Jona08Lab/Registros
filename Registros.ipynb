# %%
import pandas as pd

# %%
df = pd.read_csv("Registros.csv")

# %%
df
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                30/01/2024      0ed066       2      12          16     2
# 1                30/01/2024      7aeb5d       2      12           3     1
# 2                30/01/2024      64d705       1       6          18     1
# 3                30/01/2024      8b1a04       2       9          14     1
# 4                30/01/2024      78d4d5       2      12           3     1
# ...                     ...         ...     ...     ...         ...   ...
# 1048570          30/01/2024     gaa738c       2       4          24     2
# 1048571          30/01/2024     g89a3ff       2       4          28     1
# 1048572          30/01/2024     g7cfa1f       1      12          19     2
# 1048573          30/01/2024     g62a7e5       2      12           9     1
# 1048574          30/01/2024     gdb8581       1      12          11     2
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...
